# %% [markdown]
# <a href="https://colab.research.google.com/github/kiyounghan/dataanalysis26/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/BussemakerLab/PyProBound.git
# Out:
# ...
#   Cloning https://github.com/BussemakerLab/PyProBound.git to /tmp/pip-req-build-2yswothu
#   Running command git clone --filter=blob:none --quiet https://github.com/BussemakerLab/PyProBound.git /tmp/pip-req-build-2yswothu
#   Resolved https://github.com/BussemakerLab/PyProBound.git to commit 6f6ac76d6b2062360b0693edc474dd2e946b2b8a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 91.5 MB/s eta 0:00:00
# ...
#   Created wheel for pyprobound: filename=pyprobound-1.5.0-py3-none-any.whl size=99806 sha256=7718552471641dc10701165adc21689cea4148f5d84edc39df77b7e55a9b3114
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vb48kb32/wheels/bd/a1/de/d90ab2d94cfb2b53b7bc08aafc9fc206bedd22449ca678ef3c
# Successfully built pyprobound
# ...
